# %% [markdown]
# <a href="https://colab.research.google.com/github/akhterquddus-ops/genai-course/blob/main/Calculator_operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age_str = "25"

# %%
age_num = int(age_str)         # Now it is 25 (number)

# %%
num1 = float(input("Enter first number: "))
# Out:
# Enter first number: 342

# %%
num2 = float(input("Enter second number: "))
# Out:
# Enter second number: 232

# %%
print(f"\nResults for {num1} and {num2}:")
# Out:
# Results for 342.0 and 232.0:

# %%
print(f"  Addition:       {num1 + num2}")
# Out:
#   Addition:       574.0

# %%
print(f"  Subtraction:    {num1 - num2}")
# Out:
#   Subtraction:    110.0

# %%
print(f"  Multiplication: {num1 * num2}")
# Out:
#   Multiplication: 79344.0

# %%
print(f"  Division:       {num1 / num2:.2f}")
# Out:
#   Division:       1.47

# %%
print(f"  Power:          {num1 ** num2}")
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipykernel_2843/2103409866.py in <cell line: 0>()
# ----> 1 print(f"  Power:          {num1 ** num2}")
#
# OverflowError: (34, 'Numerical result out of range')

# %%
print(f"  Is num1 > num2? {num1 > num2}")
# Out:
#   Is num1 > num2? True
