# %% [markdown]
# <a href="https://colab.research.google.com/github/akhterquddus-ops/genai-course/blob/main/Interactive1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
	a = 10
	b = 3
	print(f"Add:   {a + b}")
# Out:
# Add:   13

# %%
name = input("What is your name? ")
city = input("Which city are you from? ")
age = int(input("How old are you? "))
# Out:
# What is your name? Akhter
# Which city are you from? Karachi
# How old are you? 45
