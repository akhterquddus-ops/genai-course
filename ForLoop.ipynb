# %% [markdown]
# <a href="https://colab.research.google.com/github/akhterquddus-ops/genai-course/blob/main/ForLoop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Age: "))
# Out:
# Age: 2323

# %%
 if age >= 18:
				print("You can vote!")
elif age >= 13:
				print("Teenager!")
else:
				print("Too young.")
# Out:
# You can vote!
