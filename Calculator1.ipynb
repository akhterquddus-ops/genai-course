# %% [markdown]
# <a href="https://colab.research.google.com/github/akhterquddus-ops/genai-course/blob/main/Calculator1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
	a = 10
	b = 3
	print(f"Add:   {a + b}")
# Out:
# Add:   13
