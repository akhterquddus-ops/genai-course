# %% [markdown]
# <a href="https://colab.research.google.com/github/akhterquddus-ops/genai-course/blob/main/Class_Password.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
password = ""

# %%
while password != "python123":
				password = input("Enter password: ")
if password != "python123":
				print("Wrong! Try again.")
print("Access granted! Welcome!")
# Out:
# Enter password: abdc
# Enter password: adss
# Enter password: aswqa
# Enter password: pyton123
# Enter password: python123
# Access granted! Welcome!
